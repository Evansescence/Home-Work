# %%
# %matplotlib inline
# Dependencies and Setup
import random
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# File to Load (Remember to change these)
city_data_to_load = "data/city_data.csv"

ride_data_to_load = "data/ride_data.csv"

# Read the City and Ride Data
cdtl= pd.read_csv(city_data_to_load)
rdtl= pd.read_csv(ride_data_to_load)
# Combine the data into a single dataset
mergecolumns= pd.merge(rdtl,cdtl,on="city", how="left")
# Display the data table for preview
mergecolumns.head(20)
# Out:
#                    city                 date   fare        ride_id  \
# 0    Lake Jonathanshire  2018-01-14 10:14:22  13.83  5739410935873
# 1    South Michelleport  2018-03-04 18:24:09  30.24  2343912425577
# 2    Port Samanthamouth  2018-02-24 04:29:00  33.44  2005065760003
# 3            Rodneyfort  2018-02-10 23:22:03  23.44  5149245426178
# 4            South Jack  2018-03-06 04:28:35  34.58  3908451377344
# 5          South Latoya  2018-03-11 12:26:48   9.52  1994999424437
# 6         New Paulville  2018-02-27 11:17:56  43.25   793208410091
# 7          Simpsonburgh  2018-04-26 00:43:24  35.98   111953927754
# 8       South Karenland  2018-01-08 03:28:48  35.09  7995623208694
# 9         North Jasmine  2018-03-09 06:26:29  42.81  5327642267789
# 10  New Kimberlyborough  2018-02-07 01:10:11   9.34  7992781920789
# 11          West Angela  2018-01-12 01:45:27  26.86  4820052223501
# 12           Rodneyfort  2018-03-02 18:03:20  44.26  2494064867705
# ...

# %%
urbane = mergecolumns.groupby['city'].count()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-231-9109ea96c3de> in <module>()
# ----> 1 urbane = mergecolumns.groupby['city'].count()
#
# TypeError: 'method' object is not subscriptable

# %%
rustic = mergecolumns["type","city"].head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('type', 'city')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-227-ac021b2f7742> in <module>()
# ...

# %% [markdown]
# ## Bubble Plot of Ride Sharing Data

# %%
mergecolumns['type'].value_counts()
# Out:
# Urban       1625
# Suburban     625
# Rural        125
# Name: type, dtype: int64

# %%
city_types = ["Urban", "Suburban", "Rural"]
type_city = mergecolumns.groupby(["type"]).sum()
type_city = mergecolumns.groupby(["type"]).sum()
type_city
# Out:
#               fare           ride_id  driver_count
# type
# Rural      4327.93   580968240341287           537
# Suburban  19356.33  3106884522576766          8570
# Urban     39854.38  7919412664056093         59602

# %%
Type_and_fare = type_city[["fare"]].mean()
driver_and_fare = type_city[["driver_count"]].mean
Type_and_fare
# Out:
# fare    21179.546667
# dtype: float64

# %%
cities= pd.merge(city_types,type_city,on="city", how="left")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-173-83e0f369741b> in <module>()
# ----> 1 cities= pd.merge(city_types,type_city,on="city", how="left")
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      58                          right_index=right_index, sort=sort, suffixes=suffixes,
#      59                          copy=copy, indicator=indicator,
# ---> 60                          validate=validate)
#      61     return op.get_result()
#      62
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     521         if not isinstance(left, DataFrame):
# ...

# %%
city_types = ["Urban", "Suburban", "Rural"]
type_city = mergecolumns.groupby(["type"]).sum()
urban_city = mergecolumns.groupby(["type", "driver_count"]).count()
urban_city
suburban_city = mergecolumns.groupby(["type","driver_count"]).count()
suburban_city
rural_city = mergecolumns.groupby(["type", "driver_count"]).count()
rural_city
# Out:
#                        city  date  fare  ride_id
# type     driver_count
# Rural    1               32    32    32       32
#          2               17    17    17       17
#          4               21    21    21       21
#          6               17    17    17       17
#          7               24    24    24       24
#          8                9     9     9        9
#          9                5     5     5        5
# Suburban 1               38    38    38       38
#          2               29    29    29       29
#          3               12    12    12       12
#          4               62    62    62       62
#          5               27    27    27       27
#          7               43    43    43       43
#          10              30    30    30       30
#          11              29    29    29       29
#          12              21    21    21       21
#          14              17    17    17       17
#          16              14    14    14       14
# ...

# %%
urban_city = mergecolumns.groupby(["type", "driver_count"]).count()
urban_city
suburban_city = type_city.groupby(["type","driver_count"]).count()
suburban_city
rural_city = type_city.groupby(["type", "driver_count"]).count()
rural_city
# Out:
#                        fare  ride_id
# type     driver_count
# Rural    537              1        1
# Suburban 8570             1        1
# Urban    59602            1        1

# %%
#urbanid fare driver_count count mean mean.  Merge then filter and save as new dataframe
city_drivers = mergecolumns["city"].value_counts()
city_drivers
# Out:
# West Angela             39
# South Karenland         38
# North Jason             35
# Liumouth                33
# Port Frank              33
# South Evanton           31
# West Robert             31
# South Michelleport      31
# South Phillip           31
# Royland                 30
# Justinberg              30
# New Kimberlyborough     30
# North Jasmine           30
# West Anthony            30
# East Kaylahaven         29
# Richardfort             28
# West Heidi              28
# Loganberg               28
# Hurleymouth             28
# Karenside               28
# East Marymouth          27
# Christopherfurt         27
# Josephside              27
# Carriemouth             27
# West Josephberg         26
# West Christopherberg    26
# Lake Danielberg         26
# Lake Robertside         25
# Jerryton                25
# North Madeline          25
#                         ..
# North Markport          14
# North Richardhaven      14
# Williamsonville         14
# ...

# %%
Urbans = mergecolumns.groupby(["city", "driver_count", "type"]).count()
Urbans
# Out:
#                                             date  fare  ride_id
# city                 driver_count type
# Amandaburgh          12           Urban       18    18       18
# Barajasview          26           Urban       22    22       22
# Barronchester        11           Suburban    16    16       16
# Bethanyland          22           Suburban    18    18       18
# Bradshawfurt         7            Rural       10    10       10
# Brandonfort          10           Suburban    19    19       19
# Carriemouth          52           Urban       27    27       27
# Christopherfurt      41           Urban       27    27       27
# Colemanland          23           Suburban    22    22       22
# Davidfurt            23           Suburban    17    17       17
# Deanville            49           Urban       19    19       19
# East Aaronbury       7            Suburban     9     9        9
# East Danielview      22           Suburban    17    17       17
# ...

# %%
Urban_drivers_count = mergecolumns.groupby[("driver_count")].count()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-219-93d40447d489> in <module>()
# ----> 1 Urban_drivers_count = mergecolumns.groupby[("driver_count")].count()
#
# TypeError: 'method' object is not subscriptable

# %%
# Obtain the x and y coordinates for each of the three city types




x_axis = (city_drivers)
x_axis
y_axis = (city_drivers)
y_axis

city_Types = ["Urban", "Suburban", "Rural"]

# Build the scatter plots for each city types
plt.scatter(x_axis , y_axis, marker="o", facecolors="red", edgecolors="black", alpha=0.75)
# Incorporate the other graph properties

# Create a legend
plt.title("Pyber Ride Sharing Data (2016)")
plt.xlabel("Total Number of rides (Per City)")
plt.ylabel("Average Fare($)")
# Incorporate a text label regarding circle size

# Save Figure
# Out:
# Text(0,0.5,'Average Fare($)')

# %%
colors = ["red", "white", "blue"]
plt.pie(city_drivers, labels=city_drivers, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=90)
plt.axis("equal")
plt.show()

# %%
# Incorporate the other graph properties

# Create a legend

# Incorporate a text label regarding circle size

# Save Figure

# %%
# Show plot
plt.show()

# %% [markdown]
# ## Total Fares by City Type

# %%
# Calculate Type Percents

# Build Pie Chart
city_type.pie()
# Save Figure
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-9a7ef711cf08> in <module>()
#       2
#       3 # Build Pie Chart
# ----> 4 city_type.pie()
#       5 # Save Figure
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'pie'

# %%
# Show Figure
plt.show()

# %% [markdown]
# ## Total Rides by City Type

# %%
# Calculate Ride Percents

# Build Pie Chart

# Save Figure

# %%
# Show Figure
plt.show()

# %% [markdown]
# ## Total Drivers by City Type

# %%
# Calculate Driver Percents

# Build Pie Charts

# Save Figure

# %%
# Show Figure
plt.show()
